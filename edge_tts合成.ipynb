# %%
import edge_tts
import asyncio
import util   
import config
import json
from IPython.display import Audio
from edge_tts_vc_func import RVCSpeakers
# Out:
# 2023-07-25 18:39:05 | INFO | fairseq.tasks.text_to_speech | Please install tensorboardX: pip install tensorboardX
# 2023-07-25 18:39:05 | INFO | faiss.loader | Loading faiss with AVX2 support.
# 2023-07-25 18:39:05 | INFO | faiss.loader | Successfully loaded faiss with AVX2 support.

# %%
rvc = RVCSpeakers(hubert_model_path='hubert_base.pt', rvc_config_file='multi_config.json')
# Out:
# 2023-07-25 18:39:07 | INFO | fairseq.tasks.hubert_pretraining | current directory is /media/gpt4-pdf-chatbot-langchain/RVC-Speakers
# 2023-07-25 18:39:07 | INFO | fairseq.tasks.hubert_pretraining | HubertPretrainingTask Config {'_name': 'hubert_pretraining', 'data': 'metadata', 'fine_tuning': False, 'labels': ['km'], 'label_dir': 'label', 'label_rate': 50.0, 'sample_rate': 16000, 'normalize': False, 'enable_padding': False, 'max_keep_size': None, 'max_sample_size': 250000, 'min_sample_size': 32000, 'single_target': False, 'random_crop': True, 'pad_audio': False}
# 2023-07-25 18:39:07 | INFO | fairseq.models.hubert.hubert | HubertModel Config: {'_name': 'hubert', 'label_rate': 50.0, 'extractor_mode': default, 'encoder_layers': 12, 'encoder_embed_dim': 768, 'encoder_ffn_embed_dim': 3072, 'encoder_attention_heads': 12, 'activation_fn': gelu, 'layer_type': transformer, 'dropout': 0.1, 'attention_dropout': 0.1, 'activation_dropout': 0.0, 'encoder_layerdrop': 0.05, 'dropout_input': 0.1, 'dropout_features': 0.1, 'final_dim': 256, 'untie_final_proj': True, 'layer_norm_first': False, 'conv_feature_layers': '[(512,10,5)] + [(512,3,2)] * 4 + [(512,2,2)] * 2', 'conv_bias': False, 'logit_temp': 0.1, 'target_glu': False, 'feature_grad_mult': 0.1, 'mask_length': 10, 'mask_prob': 0.8, 'mask_selection': static, 'mask_other': 0.0, 'no_mask_overlap': False, 'mask_min_space': 1, 'mask_channel_length': 10, 'mask_channel_prob': 0.0, 'mask_channel_selection': static, 'mask_channel_other': 0.0, 'no_mask_channel_overlap': False, 'mask_channel_min_space': 1, 'conv_pos': 128, 'conv_pos_groups': 16, 'latent_temp': [2.0, 0.5, 0.999995], 'skip_masked': False, 'skip_nomask': False, 'checkpoint_activations': False, 'required_seq_len_multiple': 2, 'depthwise_conv_kernel_size': 31, 'attn_type': '', 'pos_enc_type': 'abs', 'fp16': False}
# Loading model: yiqing
# gin_channels: 256 self.spk_embed_dim: 109
# <All keys matched successfully>
# Loading model: bob
# gin_channels: 256 self.spk_embed_dim: 109
# <All keys matched successfully>
# Loading model: arianagrande
# gin_channels: 256 self.spk_embed_dim: 109
# <All keys matched successfully>
# Loading model: syz
# gin_channels: 256 self.spk_embed_dim: 109
# <All keys matched successfully>
# Loading model: lulu
# gin_channels: 256 self.spk_embed_dim: 109
# <All keys matched successfully>
# Models loaded: 5

# %%
async def edge_tts_vc_func(
        rvc: RVCSpeakers,input_text, model_index, tts_speaker, pitch_adjust, f0_method, 
        feat_ratio, filter_radius, rms_mix_rate, resample_option,
        rate: str, volume: str
):
    if input_text is None:
        return (None, 'Please provide TTS text.')

    if tts_speaker is None:
        return (None, 'Please select TTS speaker.')

    if model_index is None:
        return (None, 'Please select a model.')

    speaker = rvc.tts_speakers_list[tts_speaker]['ShortName']
    (tts_np, tts_sr) = await util.call_edge_tts_config(speaker_name=speaker, text=input_text,rate=rate, volume=volume)
    return rvc.vc_func(
        (tts_sr, tts_np),
        model_index,
        pitch_adjust,
        f0_method,
        feat_ratio,
        filter_radius,
        rms_mix_rate,
        resample_option
    )

# %%
loaded_models=[
        '%s - %s' % (
            m['metadata'].get('source', 'Unknown'),
            m['metadata'].get('name')
        )
        for m in rvc.loaded_models
]
loaded_models
# Out:
# ['Bilibili - 一清清清',
#  'ALL - Bob Sponge',
#  'ALL - Ariana Grande',
#  'ALL - Stefanie Sun',
#  '露露 - 露露']

# %%
model_index = loaded_models.index('露露 - 露露')
model_index
# Out:
# 4

# %%
tts_speaker = [
    '%s (%s)' % (
        s['FriendlyName'],
        s['Gender'], 
    )
    for s in rvc.tts_speakers_list
]

# %%
"""

 'Microsoft HiuGaai Online (Natural) - Chinese (Cantonese Traditional) (Female)',
 'Microsoft HiuMaan Online (Natural) - Chinese (Hong Kong) (Female)',
 'Microsoft WanLung Online (Natural) - Chinese (Hong Kong) (Male)',
 'Microsoft Xiaoxiao Online (Natural) - Chinese (Mainland) (Female)',
 'Microsoft Xiaoyi Online (Natural) - Chinese (Mainland) (Female)',
 'Microsoft Yunjian Online (Natural) - Chinese (Mainland) (Male)',
 'Microsoft Yunxi Online (Natural) - Chinese (Mainland) (Male)',
 'Microsoft Yunxia Online (Natural) - Chinese (Mainland) (Male)',
 'Microsoft Yunyang Online (Natural) - Chinese (Mainland) (Male)',
 'Microsoft Xiaobei Online (Natural) - Chinese (Northeastern Mandarin) (Female)',
 'Microsoft HsiaoChen Online (Natural) - Chinese (Taiwan) (Female)',
 'Microsoft YunJhe Online (Natural) - Chinese (Taiwan) (Male)',
 'Microsoft HsiaoYu Online (Natural) - Chinese (Taiwanese Mandarin) (Female)',
 'Microsoft Xiaoni Online (Natural) - Chinese (Zhongyuan Mandarin Shaanxi) (Female)',
"""
tts_speaker_index = tts_speaker.index('Microsoft Xiaoxiao Online (Natural) - Chinese (Mainland) (Female)')
tts_speaker_index
# Out:
# 55

# %%
value="封建五爵，井田刑狱"
# 变调
pitch_adjust=0
f0_method =['pm', 'harvest']

feat_ratio=0.6
filter_radius=3
rms_mix_rate=1
resample_rate='Disable resampling'

rate='-20%'
volume='-50%' 
out_sr, output_audio = await edge_tts_vc_func(rvc,value,model_index,tts_speaker_index,pitch_adjust,f0_method[1],
                                feat_ratio, filter_radius, rms_mix_rate, resample_rate,
                                   rate=rate, volume=volume)
# Out:
# ffmpeg version n6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 13.1.1 (GCC) 20230429
#   configuration: --prefix=/usr --disable-debug --disable-static --disable-stripping --enable-amf --enable-avisynth --enable-cuda-llvm --enable-lto --enable-fontconfig --enable-gmp --enable-gnutls --enable-gpl --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libdav1d --enable-libdrm --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libiec61883 --enable-libjack --enable-libjxl --enable-libmfx --enable-libmodplug --enable-libmp3lame --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librav1e --enable-librsvg --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtheora --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxcb --enable-libxml2 --enable-libxvid --enable-libzimg --enable-nvdec --enable-nvenc --enable-opencl --enable-opengl --enable-shared --enable-version3 --enable-vulkan
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mp3, from 'fd:':
#   Duration: N/A, start: 0.000000, bitrate: 48 kb/s
#   Stream #0:0: Audio: mp3, 24000 Hz, mono, fltp, 48 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Output #0, wav, to 'pipe:':
#   Metadata:
#     ISFT            : Lavf60.3.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 24000 Hz, mono, s16, 384 kb/s
#     Metadata:
#       encoder         : Lavc60.3.100 pcm_s16le
# size=     159kB time=00:00:03.36 bitrate= 386.9kbits/s speed=1.09e+03x
# video:0kB audio:159kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.048020%
# Traceback (most recent call last):
#   File "/media/gpt4-pdf-chatbot-langchain/RVC-Speakers/vc_infer_pipeline.py", line 229, in pipeline
#     index = faiss.read_index(file_index)
#   File "/media/gpt4-pdf-chatbot-langchain/pyenv-test-1/lib/python3.10/site-packages/faiss/swigfaiss_avx2.py", line 9783, in read_index
#     return _swigfaiss_avx2.read_index(*args)
# RuntimeError: Error in faiss::InvertedLists* faiss::read_InvertedLists(faiss::IOReader*, int) at /project/faiss/faiss/impl/index_read.cpp:211: Error: 'ret == (n * ails->code_size)' failed: read error in model/lulu/added_IVF256_Flat_nprobe_1_lulu-epoch_v2.index: 3613 != 113664 (Success)
# npy: 0.5095803737640381s, f0: 2.2255048751831055s, infer: 0.4648306369781494s

# %%
from scipy.io.wavfile import write as write_wav

# save audio to disk
write_wav(f"test.wav", out_sr, output_audio) 

# play text in notebook
Audio(output_audio, rate=out_sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
json_data = '''
[
    {
        "title": "菩萨蛮 其一",
        "paragraphs": [
            "小山重叠金明灭，鬓云欲度香腮雪。",
            "懒起画蛾眉，弄妆梳洗迟。",
            "照花前后镜，花面交 相映。",
            "新帖绣罗襦，双双金鹧鸪。"
        ],
        "author": "温庭筠",
        "rhythmic": "菩萨蛮",
        "notes": [
            "1.小山--写女子的隔夜残妆。小山：女子画眉的式样之一。小山重叠：眉晕褪色。金：额黄，在额上涂黄色。金明灭：褪色的额黄明暗不匀。",
            "2.鬓云欲度--鬓发撩乱如云，低垂下来。香腮雪：洁白如雪的香腮。",
            "3.照花--对镜簪花。用前镜、后镜对照以瞻顾后影。",
            "4.双双--罗襦上用金线绣的成双的鹧鸪鸟。反衬自身孤独。"
        ]
    }
]
'''

# %%
import json
import pyaudio
import numpy as np
import asyncio

#conda install -c anaconda portaudio    


async def play_audio(audio_data, rate):
    loop = asyncio.get_event_loop()
    p = pyaudio.PyAudio()

    def callback(in_data, frame_count, time_info, status):
        nonlocal audio_data
        data = audio_data[:frame_count]
        audio_data = audio_data[frame_count:]
        return (data.tobytes(), pyaudio.paContinue)

    stream = p.open(format=pyaudio.paInt16,
                    channels=1,
                    rate=rate,
                    output=True,
                    stream_callback=callback)

    stream.start_stream()
    while stream.is_active():
        await asyncio.sleep(0.1)

    stream.stop_stream()
    stream.close()
    p.terminate()

# %%
import time


async def text_to_speech(data):
    p = pyaudio.PyAudio()
    stream = p.open(format=pyaudio.paInt16,
                    channels=1,
                    rate=22050,
                    output=True)
    for item in data:
        
        timestamp = int(time.time())
        for key, value in item.items():
            
            if isinstance(value, str): 
                out_sr, output_audio = await edge_tts_vc_func(rvc,value,model_index,tts_speaker_index,pitch_adjust,f0_method[1],
                                        feat_ratio, filter_radius, rms_mix_rate, resample_rate,
                                           rate=rate, volume=volume)
                 
                # save audio to disk
                write_wav(f"wav/{timestamp}_{key}.wav", out_sr, output_audio) 
                await play_audio(output_audio,out_sr)
            elif isinstance(value, list):
                for i, para in enumerate(value): 
                    out_sr, output_audio = await edge_tts_vc_func(rvc,para,model_index,tts_speaker_index,pitch_adjust,f0_method[1],
                                        feat_ratio, filter_radius, rms_mix_rate, resample_rate,
                                           rate=rate, volume=volume)
                    
                    # save audio to disk
                    write_wav(f"wav/{timestamp}_{key}_{i}.wav", out_sr, output_audio) 
                    await play_audio(output_audio,out_sr)

# %%
import os

'''
获取输入文件夹内的所有wav文件，并返回文件名全称列表
'''
def file_name(file_dir):
    L = []
    for root, dirs, files in os.walk(file_dir):
        print(files)
        for file in files:
            if os.path.splitext(file)[1] == '.json':
                filename=os.path.join(root, file)
                L.append(filename)
    return L 

def read_text_file(filename):
    try:
        with open(filename, 'r', encoding='utf-8') as file:
            content = file.read()
        return content
    except FileNotFoundError:
        print(f"File '{filename}' not found.")
        return None
    except Exception as e:
        print("An error occurred while reading the file:", e)
        return None

    
json_dir="/media/checkpoint/chinese-poetry/曹操诗集/"#文件夹
json_texts=file_name(json_dir)#获取文件夹内的所有文件
print(json_texts)
for text in json_texts:
    text_content = read_text_file(text)
    data = json.loads(text_content)
    await text_to_speech(data)
# Out:
# ['README.md', 'caocao.json']
# ['/media/checkpoint/chinese-poetry/曹操诗集/caocao.json']
# ffmpeg version n6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 13.1.1 (GCC) 20230429
#   configuration: --prefix=/usr --disable-debug --disable-static --disable-stripping --enable-amf --enable-avisynth --enable-cuda-llvm --enable-lto --enable-fontconfig --enable-gmp --enable-gnutls --enable-gpl --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libdav1d --enable-libdrm --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libiec61883 --enable-libjack --enable-libjxl --enable-libmfx --enable-libmodplug --enable-libmp3lame --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librav1e --enable-librsvg --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtheora --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxcb --enable-libxml2 --enable-libxvid --enable-libzimg --enable-nvdec --enable-nvenc --enable-opencl --enable-opengl --enable-shared --enable-version3 --enable-vulkan
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mp3, from 'fd:':
#   Duration: N/A, start: 0.000000, bitrate: 48 kb/s
#   Stream #0:0: Audio: mp3, 24000 Hz, mono, fltp, 48 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Output #0, wav, to 'pipe:':
#   Metadata:
#     ISFT            : Lavf60.3.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 24000 Hz, mono, s16, 384 kb/s
#     Metadata:
#       encoder         : Lavc60.3.100 pcm_s16le
# size=      83kB time=00:00:01.75 bitrate= 389.6kbits/s speed= 830x
# video:0kB audio:83kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.091498%
# Traceback (most recent call last):
#   File "/media/gpt4-pdf-chatbot-langchain/RVC-Speakers/vc_infer_pipeline.py", line 229, in pipeline
#     index = faiss.read_index(file_index)
#   File "/media/gpt4-pdf-chatbot-langchain/pyenv-test-1/lib/python3.10/site-packages/faiss/swigfaiss_avx2.py", line 9783, in read_index
#     return _swigfaiss_avx2.read_index(*args)
# RuntimeError: Error in faiss::InvertedLists* faiss::read_InvertedLists(faiss::IOReader*, int) at /project/faiss/faiss/impl/index_read.cpp:211: Error: 'ret == (n * ails->code_size)' failed: read error in model/lulu/added_IVF256_Flat_nprobe_1_lulu-epoch_v2.index: 3613 != 113664 (Success)
# npy: 0.024892330169677734s, f0: 1.5089645385742188s, infer: 0.12712907791137695s
# ffmpeg version n6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 13.1.1 (GCC) 20230429
#   configuration: --prefix=/usr --disable-debug --disable-static --disable-stripping --enable-amf --enable-avisynth --enable-cuda-llvm --enable-lto --enable-fontconfig --enable-gmp --enable-gnutls --enable-gpl --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libdav1d --enable-libdrm --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libiec61883 --enable-libjack --enable-libjxl --enable-libmfx --enable-libmodplug --enable-libmp3lame --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librav1e --enable-librsvg --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtheora --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxcb --enable-libxml2 --enable-libxvid --enable-libzimg --enable-nvdec --enable-nvenc --enable-opencl --enable-opengl --enable-shared --enable-version3 --enable-vulkan
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mp3, from 'fd:':
#   Duration: N/A, start: 0.000000, bitrate: 48 kb/s
#   Stream #0:0: Audio: mp3, 24000 Hz, mono, fltp, 48 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Output #0, wav, to 'pipe:':
#   Metadata:
#     ISFT            : Lavf60.3.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 24000 Hz, mono, s16, 384 kb/s
#     Metadata:
#       encoder         : Lavc60.3.100 pcm_s16le
# size=     135kB time=00:00:02.85 bitrate= 387.4kbits/s speed=1.17e+03x
# video:0kB audio:135kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.056424%
# Traceback (most recent call last):
#   File "/media/gpt4-pdf-chatbot-langchain/RVC-Speakers/vc_infer_pipeline.py", line 229, in pipeline
#     index = faiss.read_index(file_index)
#   File "/media/gpt4-pdf-chatbot-langchain/pyenv-test-1/lib/python3.10/site-packages/faiss/swigfaiss_avx2.py", line 9783, in read_index
#     return _swigfaiss_avx2.read_index(*args)
# RuntimeError: Error in faiss::InvertedLists* faiss::read_InvertedLists(faiss::IOReader*, int) at /project/faiss/faiss/impl/index_read.cpp:211: Error: 'ret == (n * ails->code_size)' failed: read error in model/lulu/added_IVF256_Flat_nprobe_1_lulu-epoch_v2.index: 3613 != 113664 (Success)
# npy: 0.025900602340698242s, f0: 1.9332213401794434s, infer: 0.1336216926574707s
# ffmpeg version n6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 13.1.1 (GCC) 20230429
#   configuration: --prefix=/usr --disable-debug --disable-static --disable-stripping --enable-amf --enable-avisynth --enable-cuda-llvm --enable-lto --enable-fontconfig --enable-gmp --enable-gnutls --enable-gpl --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libdav1d --enable-libdrm --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libiec61883 --enable-libjack --enable-libjxl --enable-libmfx --enable-libmodplug --enable-libmp3lame --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librav1e --enable-librsvg --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtheora --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxcb --enable-libxml2 --enable-libxvid --enable-libzimg --enable-nvdec --enable-nvenc --enable-opencl --enable-opengl --enable-shared --enable-version3 --enable-vulkan
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mp3, from 'fd:':
#   Duration: N/A, start: 0.000000, bitrate: 48 kb/s
#   Stream #0:0: Audio: mp3, 24000 Hz, mono, fltp, 48 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Output #0, wav, to 'pipe:':
#   Metadata:
#     ISFT            : Lavf60.3.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 24000 Hz, mono, s16, 384 kb/s
#     Metadata:
#       encoder         : Lavc60.3.100 pcm_s16le
# size=     161kB time=00:00:03.40 bitrate= 386.9kbits/s speed=1.42e+03x
# video:0kB audio:161kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.047348%
# Traceback (most recent call last):
#   File "/media/gpt4-pdf-chatbot-langchain/RVC-Speakers/vc_infer_pipeline.py", line 229, in pipeline
#     index = faiss.read_index(file_index)
#   File "/media/gpt4-pdf-chatbot-langchain/pyenv-test-1/lib/python3.10/site-packages/faiss/swigfaiss_avx2.py", line 9783, in read_index
#     return _swigfaiss_avx2.read_index(*args)
# RuntimeError: Error in faiss::InvertedLists* faiss::read_InvertedLists(faiss::IOReader*, int) at /project/faiss/faiss/impl/index_read.cpp:211: Error: 'ret == (n * ails->code_size)' failed: read error in model/lulu/added_IVF256_Flat_nprobe_1_lulu-epoch_v2.index: 3613 != 113664 (Success)
# npy: 0.026148319244384766s, f0: 2.0922703742980957s, infer: 0.13466644287109375s
# ffmpeg version n6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 13.1.1 (GCC) 20230429
#   configuration: --prefix=/usr --disable-debug --disable-static --disable-stripping --enable-amf --enable-avisynth --enable-cuda-llvm --enable-lto --enable-fontconfig --enable-gmp --enable-gnutls --enable-gpl --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libdav1d --enable-libdrm --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libiec61883 --enable-libjack --enable-libjxl --enable-libmfx --enable-libmodplug --enable-libmp3lame --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librav1e --enable-librsvg --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtheora --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxcb --enable-libxml2 --enable-libxvid --enable-libzimg --enable-nvdec --enable-nvenc --enable-opencl --enable-opengl --enable-shared --enable-version3 --enable-vulkan
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mp3, from 'fd:':
#   Duration: N/A, start: 0.000000, bitrate: 48 kb/s
#   Stream #0:0: Audio: mp3, 24000 Hz, mono, fltp, 48 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Output #0, wav, to 'pipe:':
#   Metadata:
#     ISFT            : Lavf60.3.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 24000 Hz, mono, s16, 384 kb/s
#     Metadata:
#       encoder         : Lavc60.3.100 pcm_s16le
# size=     162kB time=00:00:03.43 bitrate= 386.9kbits/s speed=1.23e+03x
# video:0kB audio:162kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.047020%
# Traceback (most recent call last):
#   File "/media/gpt4-pdf-chatbot-langchain/RVC-Speakers/vc_infer_pipeline.py", line 229, in pipeline
#     index = faiss.read_index(file_index)
#   File "/media/gpt4-pdf-chatbot-langchain/pyenv-test-1/lib/python3.10/site-packages/faiss/swigfaiss_avx2.py", line 9783, in read_index
#     return _swigfaiss_avx2.read_index(*args)
# RuntimeError: Error in faiss::InvertedLists* faiss::read_InvertedLists(faiss::IOReader*, int) at /project/faiss/faiss/impl/index_read.cpp:211: Error: 'ret == (n * ails->code_size)' failed: read error in model/lulu/added_IVF256_Flat_nprobe_1_lulu-epoch_v2.index: 3613 != 113664 (Success)
# npy: 0.027090072631835938s, f0: 2.2860493659973145s, infer: 0.1294395923614502s
# ffmpeg version n6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 13.1.1 (GCC) 20230429
#   configuration: --prefix=/usr --disable-debug --disable-static --disable-stripping --enable-amf --enable-avisynth --enable-cuda-llvm --enable-lto --enable-fontconfig --enable-gmp --enable-gnutls --enable-gpl --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libdav1d --enable-libdrm --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libiec61883 --enable-libjack --enable-libjxl --enable-libmfx --enable-libmodplug --enable-libmp3lame --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librav1e --enable-librsvg --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtheora --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxcb --enable-libxml2 --enable-libxvid --enable-libzimg --enable-nvdec --enable-nvenc --enable-opencl --enable-opengl --enable-shared --enable-version3 --enable-vulkan
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mp3, from 'fd:':
#   Duration: N/A, start: 0.000000, bitrate: 48 kb/s
#   Stream #0:0: Audio: mp3, 24000 Hz, mono, fltp, 48 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Output #0, wav, to 'pipe:':
#   Metadata:
#     ISFT            : Lavf60.3.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 24000 Hz, mono, s16, 384 kb/s
#     Metadata:
#       encoder         : Lavc60.3.100 pcm_s16le
# size=     160kB time=00:00:03.38 bitrate= 386.9kbits/s speed=1.16e+03x
# video:0kB audio:160kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.047682%
# Traceback (most recent call last):
#   File "/media/gpt4-pdf-chatbot-langchain/RVC-Speakers/vc_infer_pipeline.py", line 229, in pipeline
#     index = faiss.read_index(file_index)
#   File "/media/gpt4-pdf-chatbot-langchain/pyenv-test-1/lib/python3.10/site-packages/faiss/swigfaiss_avx2.py", line 9783, in read_index
#     return _swigfaiss_avx2.read_index(*args)
# RuntimeError: Error in faiss::InvertedLists* faiss::read_InvertedLists(faiss::IOReader*, int) at /project/faiss/faiss/impl/index_read.cpp:211: Error: 'ret == (n * ails->code_size)' failed: read error in model/lulu/added_IVF256_Flat_nprobe_1_lulu-epoch_v2.index: 3613 != 113664 (Success)
# npy: 0.026048898696899414s, f0: 2.0428779125213623s, infer: 0.13992691040039062s
# ffmpeg version n6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 13.1.1 (GCC) 20230429
#   configuration: --prefix=/usr --disable-debug --disable-static --disable-stripping --enable-amf --enable-avisynth --enable-cuda-llvm --enable-lto --enable-fontconfig --enable-gmp --enable-gnutls --enable-gpl --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libdav1d --enable-libdrm --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libiec61883 --enable-libjack --enable-libjxl --enable-libmfx --enable-libmodplug --enable-libmp3lame --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librav1e --enable-librsvg --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtheora --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxcb --enable-libxml2 --enable-libxvid --enable-libzimg --enable-nvdec --enable-nvenc --enable-opencl --enable-opengl --enable-shared --enable-version3 --enable-vulkan
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mp3, from 'fd:':
#   Duration: N/A, start: 0.000000, bitrate: 48 kb/s
#   Stream #0:0: Audio: mp3, 24000 Hz, mono, fltp, 48 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Output #0, wav, to 'pipe:':
#   Metadata:
#     ISFT            : Lavf60.3.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 24000 Hz, mono, s16, 384 kb/s
#     Metadata:
#       encoder         : Lavc60.3.100 pcm_s16le
# size=     162kB time=00:00:03.43 bitrate= 386.9kbits/s speed=1.28e+03x
# video:0kB audio:162kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.047020%
# Traceback (most recent call last):
#   File "/media/gpt4-pdf-chatbot-langchain/RVC-Speakers/vc_infer_pipeline.py", line 229, in pipeline
#     index = faiss.read_index(file_index)
#   File "/media/gpt4-pdf-chatbot-langchain/pyenv-test-1/lib/python3.10/site-packages/faiss/swigfaiss_avx2.py", line 9783, in read_index
#     return _swigfaiss_avx2.read_index(*args)
# RuntimeError: Error in faiss::InvertedLists* faiss::read_InvertedLists(faiss::IOReader*, int) at /project/faiss/faiss/impl/index_read.cpp:211: Error: 'ret == (n * ails->code_size)' failed: read error in model/lulu/added_IVF256_Flat_nprobe_1_lulu-epoch_v2.index: 3613 != 113664 (Success)
# npy: 0.010130167007446289s, f0: 2.2159054279327393s, infer: 0.05986976623535156s
# ffmpeg version n6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 13.1.1 (GCC) 20230429
#   configuration: --prefix=/usr --disable-debug --disable-static --disable-stripping --enable-amf --enable-avisynth --enable-cuda-llvm --enable-lto --enable-fontconfig --enable-gmp --enable-gnutls --enable-gpl --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libdav1d --enable-libdrm --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libiec61883 --enable-libjack --enable-libjxl --enable-libmfx --enable-libmodplug --enable-libmp3lame --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librav1e --enable-librsvg --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtheora --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxcb --enable-libxml2 --enable-libxvid --enable-libzimg --enable-nvdec --enable-nvenc --enable-opencl --enable-opengl --enable-shared --enable-version3 --enable-vulkan
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mp3, from 'fd:':
#   Duration: N/A, start: 0.000000, bitrate: 48 kb/s
#   Stream #0:0: Audio: mp3, 24000 Hz, mono, fltp, 48 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Output #0, wav, to 'pipe:':
#   Metadata:
#     ISFT            : Lavf60.3.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 24000 Hz, mono, s16, 384 kb/s
#     Metadata:
#       encoder         : Lavc60.3.100 pcm_s16le
# size=     159kB time=00:00:03.36 bitrate= 386.9kbits/s speed=1.31e+03x
# video:0kB audio:159kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.048020%
# Traceback (most recent call last):
#   File "/media/gpt4-pdf-chatbot-langchain/RVC-Speakers/vc_infer_pipeline.py", line 229, in pipeline
#     index = faiss.read_index(file_index)
#   File "/media/gpt4-pdf-chatbot-langchain/pyenv-test-1/lib/python3.10/site-packages/faiss/swigfaiss_avx2.py", line 9783, in read_index
#     return _swigfaiss_avx2.read_index(*args)
# RuntimeError: Error in faiss::InvertedLists* faiss::read_InvertedLists(faiss::IOReader*, int) at /project/faiss/faiss/impl/index_read.cpp:211: Error: 'ret == (n * ails->code_size)' failed: read error in model/lulu/added_IVF256_Flat_nprobe_1_lulu-epoch_v2.index: 3613 != 113664 (Success)
# npy: 0.010330438613891602s, f0: 0.0007174015045166016s, infer: 0.06208467483520508s
# ffmpeg version n6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 13.1.1 (GCC) 20230429
#   configuration: --prefix=/usr --disable-debug --disable-static --disable-stripping --enable-amf --enable-avisynth --enable-cuda-llvm --enable-lto --enable-fontconfig --enable-gmp --enable-gnutls --enable-gpl --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libdav1d --enable-libdrm --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libiec61883 --enable-libjack --enable-libjxl --enable-libmfx --enable-libmodplug --enable-libmp3lame --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librav1e --enable-librsvg --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtheora --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxcb --enable-libxml2 --enable-libxvid --enable-libzimg --enable-nvdec --enable-nvenc --enable-opencl --enable-opengl --enable-shared --enable-version3 --enable-vulkan
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mp3, from 'fd:':
#   Duration: N/A, start: 0.000000, bitrate: 48 kb/s
#   Stream #0:0: Audio: mp3, 24000 Hz, mono, fltp, 48 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Output #0, wav, to 'pipe:':
#   Metadata:
#     ISFT            : Lavf60.3.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 24000 Hz, mono, s16, 384 kb/s
#     Metadata:
#       encoder         : Lavc60.3.100 pcm_s16le
# size=     160kB time=00:00:03.38 bitrate= 386.9kbits/s speed=1.3e+03x
# video:0kB audio:160kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.047682%
# Traceback (most recent call last):
#   File "/media/gpt4-pdf-chatbot-langchain/RVC-Speakers/vc_infer_pipeline.py", line 229, in pipeline
#     index = faiss.read_index(file_index)
#   File "/media/gpt4-pdf-chatbot-langchain/pyenv-test-1/lib/python3.10/site-packages/faiss/swigfaiss_avx2.py", line 9783, in read_index
#     return _swigfaiss_avx2.read_index(*args)
# RuntimeError: Error in faiss::InvertedLists* faiss::read_InvertedLists(faiss::IOReader*, int) at /project/faiss/faiss/impl/index_read.cpp:211: Error: 'ret == (n * ails->code_size)' failed: read error in model/lulu/added_IVF256_Flat_nprobe_1_lulu-epoch_v2.index: 3613 != 113664 (Success)
# npy: 0.011156558990478516s, f0: 2.325451374053955s, infer: 0.06120753288269043s
# ALSA lib pcm.c:8675:(snd_pcm_recover) underrun occurred
# ffmpeg version n6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 13.1.1 (GCC) 20230429
#   configuration: --prefix=/usr --disable-debug --disable-static --disable-stripping --enable-amf --enable-avisynth --enable-cuda-llvm --enable-lto --enable-fontconfig --enable-gmp --enable-gnutls --enable-gpl --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libdav1d --enable-libdrm --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libiec61883 --enable-libjack --enable-libjxl --enable-libmfx --enable-libmodplug --enable-libmp3lame --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librav1e --enable-librsvg --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtheora --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxcb --enable-libxml2 --enable-libxvid --enable-libzimg --enable-nvdec --enable-nvenc --enable-opencl --enable-opengl --enable-shared --enable-version3 --enable-vulkan
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mp3, from 'fd:':
#   Duration: N/A, start: 0.000000, bitrate: 48 kb/s
#   Stream #0:0: Audio: mp3, 24000 Hz, mono, fltp, 48 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Output #0, wav, to 'pipe:':
#   Metadata:
#     ISFT            : Lavf60.3.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 24000 Hz, mono, s16, 384 kb/s
#     Metadata:
#       encoder         : Lavc60.3.100 pcm_s16le
# size=     158kB time=00:00:03.33 bitrate= 386.9kbits/s speed=1.37e+03x
# video:0kB audio:158kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.048363%
# Traceback (most recent call last):
#   File "/media/gpt4-pdf-chatbot-langchain/RVC-Speakers/vc_infer_pipeline.py", line 229, in pipeline
#     index = faiss.read_index(file_index)
#   File "/media/gpt4-pdf-chatbot-langchain/pyenv-test-1/lib/python3.10/site-packages/faiss/swigfaiss_avx2.py", line 9783, in read_index
#     return _swigfaiss_avx2.read_index(*args)
# RuntimeError: Error in faiss::InvertedLists* faiss::read_InvertedLists(faiss::IOReader*, int) at /project/faiss/faiss/impl/index_read.cpp:211: Error: 'ret == (n * ails->code_size)' failed: read error in model/lulu/added_IVF256_Flat_nprobe_1_lulu-epoch_v2.index: 3613 != 113664 (Success)
# npy: 0.026965618133544922s, f0: 2.18035626411438s, infer: 0.1353909969329834s
# ALSA lib pcm.c:8675:(snd_pcm_recover) underrun occurred
# ALSA lib pcm.c:8675:(snd_pcm_recover) underrun occurred
# ffmpeg version n6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 13.1.1 (GCC) 20230429
#   configuration: --prefix=/usr --disable-debug --disable-static --disable-stripping --enable-amf --enable-avisynth --enable-cuda-llvm --enable-lto --enable-fontconfig --enable-gmp --enable-gnutls --enable-gpl --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libdav1d --enable-libdrm --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libiec61883 --enable-libjack --enable-libjxl --enable-libmfx --enable-libmodplug --enable-libmp3lame --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librav1e --enable-librsvg --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtheora --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxcb --enable-libxml2 --enable-libxvid --enable-libzimg --enable-nvdec --enable-nvenc --enable-opencl --enable-opengl --enable-shared --enable-version3 --enable-vulkan
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mp3, from 'fd:':
#   Duration: N/A, start: 0.000000, bitrate: 48 kb/s
#   Stream #0:0: Audio: mp3, 24000 Hz, mono, fltp, 48 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Output #0, wav, to 'pipe:':
#   Metadata:
#     ISFT            : Lavf60.3.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 24000 Hz, mono, s16, 384 kb/s
#     Metadata:
#       encoder         : Lavc60.3.100 pcm_s16le
# size=     154kB time=00:00:03.26 bitrate= 387.0kbits/s speed=1.32e+03x
# video:0kB audio:154kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.049422%
# Traceback (most recent call last):
#   File "/media/gpt4-pdf-chatbot-langchain/RVC-Speakers/vc_infer_pipeline.py", line 229, in pipeline
#     index = faiss.read_index(file_index)
#   File "/media/gpt4-pdf-chatbot-langchain/pyenv-test-1/lib/python3.10/site-packages/faiss/swigfaiss_avx2.py", line 9783, in read_index
#     return _swigfaiss_avx2.read_index(*args)
# RuntimeError: Error in faiss::InvertedLists* faiss::read_InvertedLists(faiss::IOReader*, int) at /project/faiss/faiss/impl/index_read.cpp:211: Error: 'ret == (n * ails->code_size)' failed: read error in model/lulu/added_IVF256_Flat_nprobe_1_lulu-epoch_v2.index: 3613 != 113664 (Success)
# npy: 0.025779008865356445s, f0: 2.273016929626465s, infer: 0.12860321998596191s
# ffmpeg version n6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 13.1.1 (GCC) 20230429
#   configuration: --prefix=/usr --disable-debug --disable-static --disable-stripping --enable-amf --enable-avisynth --enable-cuda-llvm --enable-lto --enable-fontconfig --enable-gmp --enable-gnutls --enable-gpl --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libdav1d --enable-libdrm --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libiec61883 --enable-libjack --enable-libjxl --enable-libmfx --enable-libmodplug --enable-libmp3lame --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librav1e --enable-librsvg --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtheora --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxcb --enable-libxml2 --enable-libxvid --enable-libzimg --enable-nvdec --enable-nvenc --enable-opencl --enable-opengl --enable-shared --enable-version3 --enable-vulkan
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mp3, from 'fd:':
#   Duration: N/A, start: 0.000000, bitrate: 48 kb/s
#   Stream #0:0: Audio: mp3, 24000 Hz, mono, fltp, 48 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Output #0, wav, to 'pipe:':
#   Metadata:
#     ISFT            : Lavf60.3.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 24000 Hz, mono, s16, 384 kb/s
#     Metadata:
#       encoder         : Lavc60.3.100 pcm_s16le
# size=     160kB time=00:00:03.38 bitrate= 386.9kbits/s speed=1.32e+03x
# video:0kB audio:160kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.047682%
# Traceback (most recent call last):
#   File "/media/gpt4-pdf-chatbot-langchain/RVC-Speakers/vc_infer_pipeline.py", line 229, in pipeline
#     index = faiss.read_index(file_index)
#   File "/media/gpt4-pdf-chatbot-langchain/pyenv-test-1/lib/python3.10/site-packages/faiss/swigfaiss_avx2.py", line 9783, in read_index
#     return _swigfaiss_avx2.read_index(*args)
# RuntimeError: Error in faiss::InvertedLists* faiss::read_InvertedLists(faiss::IOReader*, int) at /project/faiss/faiss/impl/index_read.cpp:211: Error: 'ret == (n * ails->code_size)' failed: read error in model/lulu/added_IVF256_Flat_nprobe_1_lulu-epoch_v2.index: 3613 != 113664 (Success)
# npy: 0.011273860931396484s, f0: 2.1114563941955566s, infer: 0.0626533031463623s
# ALSA lib pcm.c:8675:(snd_pcm_recover) underrun occurred
# ffmpeg version n6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 13.1.1 (GCC) 20230429
#   configuration: --prefix=/usr --disable-debug --disable-static --disable-stripping --enable-amf --enable-avisynth --enable-cuda-llvm --enable-lto --enable-fontconfig --enable-gmp --enable-gnutls --enable-gpl --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libdav1d --enable-libdrm --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libiec61883 --enable-libjack --enable-libjxl --enable-libmfx --enable-libmodplug --enable-libmp3lame --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librav1e --enable-librsvg --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtheora --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxcb --enable-libxml2 --enable-libxvid --enable-libzimg --enable-nvdec --enable-nvenc --enable-opencl --enable-opengl --enable-shared --enable-version3 --enable-vulkan
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mp3, from 'fd:':
#   Duration: N/A, start: 0.000000, bitrate: 48 kb/s
#   Stream #0:0: Audio: mp3, 24000 Hz, mono, fltp, 48 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Output #0, wav, to 'pipe:':
#   Metadata:
#     ISFT            : Lavf60.3.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 24000 Hz, mono, s16, 384 kb/s
#     Metadata:
#       encoder         : Lavc60.3.100 pcm_s16le
# size=     164kB time=00:00:03.48 bitrate= 386.8kbits/s speed=1.36e+03x
# video:0kB audio:164kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.046376%
# Traceback (most recent call last):
#   File "/media/gpt4-pdf-chatbot-langchain/RVC-Speakers/vc_infer_pipeline.py", line 229, in pipeline
#     index = faiss.read_index(file_index)
#   File "/media/gpt4-pdf-chatbot-langchain/pyenv-test-1/lib/python3.10/site-packages/faiss/swigfaiss_avx2.py", line 9783, in read_index
#     return _swigfaiss_avx2.read_index(*args)
# RuntimeError: Error in faiss::InvertedLists* faiss::read_InvertedLists(faiss::IOReader*, int) at /project/faiss/faiss/impl/index_read.cpp:211: Error: 'ret == (n * ails->code_size)' failed: read error in model/lulu/added_IVF256_Flat_nprobe_1_lulu-epoch_v2.index: 3613 != 113664 (Success)
# npy: 0.025714635848999023s, f0: 2.403604030609131s, infer: 0.12850213050842285s
# ALSA lib pcm.c:8675:(snd_pcm_recover) underrun occurred
# ffmpeg version n6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 13.1.1 (GCC) 20230429
#   configuration: --prefix=/usr --disable-debug --disable-static --disable-stripping --enable-amf --enable-avisynth --enable-cuda-llvm --enable-lto --enable-fontconfig --enable-gmp --enable-gnutls --enable-gpl --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libdav1d --enable-libdrm --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libiec61883 --enable-libjack --enable-libjxl --enable-libmfx --enable-libmodplug --enable-libmp3lame --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librav1e --enable-librsvg --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtheora --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxcb --enable-libxml2 --enable-libxvid --enable-libzimg --enable-nvdec --enable-nvenc --enable-opencl --enable-opengl --enable-shared --enable-version3 --enable-vulkan
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mp3, from 'fd:':
#   Duration: N/A, start: 0.000000, bitrate: 48 kb/s
#   Stream #0:0: Audio: mp3, 24000 Hz, mono, fltp, 48 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Output #0, wav, to 'pipe:':
#   Metadata:
#     ISFT            : Lavf60.3.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 24000 Hz, mono, s16, 384 kb/s
#     Metadata:
#       encoder         : Lavc60.3.100 pcm_s16le
# size=     160kB time=00:00:03.38 bitrate= 386.9kbits/s speed=1.27e+03x
# video:0kB audio:160kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.047682%
# Traceback (most recent call last):
#   File "/media/gpt4-pdf-chatbot-langchain/RVC-Speakers/vc_infer_pipeline.py", line 229, in pipeline
#     index = faiss.read_index(file_index)
#   File "/media/gpt4-pdf-chatbot-langchain/pyenv-test-1/lib/python3.10/site-packages/faiss/swigfaiss_avx2.py", line 9783, in read_index
#     return _swigfaiss_avx2.read_index(*args)
# RuntimeError: Error in faiss::InvertedLists* faiss::read_InvertedLists(faiss::IOReader*, int) at /project/faiss/faiss/impl/index_read.cpp:211: Error: 'ret == (n * ails->code_size)' failed: read error in model/lulu/added_IVF256_Flat_nprobe_1_lulu-epoch_v2.index: 3613 != 113664 (Success)
# npy: 0.011555910110473633s, f0: 2.280468225479126s, infer: 0.06053757667541504s
# ALSA lib pcm.c:8675:(snd_pcm_recover) underrun occurred
# ffmpeg version n6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 13.1.1 (GCC) 20230429
#   configuration: --prefix=/usr --disable-debug --disable-static --disable-stripping --enable-amf --enable-avisynth --enable-cuda-llvm --enable-lto --enable-fontconfig --enable-gmp --enable-gnutls --enable-gpl --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libdav1d --enable-libdrm --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libiec61883 --enable-libjack --enable-libjxl --enable-libmfx --enable-libmodplug --enable-libmp3lame --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librav1e --enable-librsvg --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtheora --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxcb --enable-libxml2 --enable-libxvid --enable-libzimg --enable-nvdec --enable-nvenc --enable-opencl --enable-opengl --enable-shared --enable-version3 --enable-vulkan
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mp3, from 'fd:':
#   Duration: N/A, start: 0.000000, bitrate: 48 kb/s
#   Stream #0:0: Audio: mp3, 24000 Hz, mono, fltp, 48 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Output #0, wav, to 'pipe:':
#   Metadata:
#     ISFT            : Lavf60.3.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 24000 Hz, mono, s16, 384 kb/s
#     Metadata:
#       encoder         : Lavc60.3.100 pcm_s16le
# size=     162kB time=00:00:03.43 bitrate= 386.9kbits/s speed=1.45e+03x
# video:0kB audio:162kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.047020%
# Traceback (most recent call last):
#   File "/media/gpt4-pdf-chatbot-langchain/RVC-Speakers/vc_infer_pipeline.py", line 229, in pipeline
#     index = faiss.read_index(file_index)
#   File "/media/gpt4-pdf-chatbot-langchain/pyenv-test-1/lib/python3.10/site-packages/faiss/swigfaiss_avx2.py", line 9783, in read_index
#     return _swigfaiss_avx2.read_index(*args)
# RuntimeError: Error in faiss::InvertedLists* faiss::read_InvertedLists(faiss::IOReader*, int) at /project/faiss/faiss/impl/index_read.cpp:211: Error: 'ret == (n * ails->code_size)' failed: read error in model/lulu/added_IVF256_Flat_nprobe_1_lulu-epoch_v2.index: 3613 != 113664 (Success)
# npy: 0.009923696517944336s, f0: 2.0805118083953857s, infer: 0.06116533279418945s
# ALSA lib pcm.c:8675:(snd_pcm_recover) underrun occurred
# ffmpeg version n6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 13.1.1 (GCC) 20230429
#   configuration: --prefix=/usr --disable-debug --disable-static --disable-stripping --enable-amf --enable-avisynth --enable-cuda-llvm --enable-lto --enable-fontconfig --enable-gmp --enable-gnutls --enable-gpl --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libdav1d --enable-libdrm --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libiec61883 --enable-libjack --enable-libjxl --enable-libmfx --enable-libmodplug --enable-libmp3lame --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librav1e --enable-librsvg --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtheora --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxcb --enable-libxml2 --enable-libxvid --enable-libzimg --enable-nvdec --enable-nvenc --enable-opencl --enable-opengl --enable-shared --enable-version3 --enable-vulkan
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mp3, from 'fd:':
#   Duration: N/A, start: 0.000000, bitrate: 48 kb/s
#   Stream #0:0: Audio: mp3, 24000 Hz, mono, fltp, 48 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Output #0, wav, to 'pipe:':
#   Metadata:
#     ISFT            : Lavf60.3.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 24000 Hz, mono, s16, 384 kb/s
#     Metadata:
#       encoder         : Lavc60.3.100 pcm_s16le
# size=     159kB time=00:00:03.36 bitrate= 386.9kbits/s speed=1.4e+03x
# video:0kB audio:159kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.048020%
# Traceback (most recent call last):
#   File "/media/gpt4-pdf-chatbot-langchain/RVC-Speakers/vc_infer_pipeline.py", line 229, in pipeline
#     index = faiss.read_index(file_index)
#   File "/media/gpt4-pdf-chatbot-langchain/pyenv-test-1/lib/python3.10/site-packages/faiss/swigfaiss_avx2.py", line 9783, in read_index
#     return _swigfaiss_avx2.read_index(*args)
# RuntimeError: Error in faiss::InvertedLists* faiss::read_InvertedLists(faiss::IOReader*, int) at /project/faiss/faiss/impl/index_read.cpp:211: Error: 'ret == (n * ails->code_size)' failed: read error in model/lulu/added_IVF256_Flat_nprobe_1_lulu-epoch_v2.index: 3613 != 113664 (Success)
# npy: 0.010081291198730469s, f0: 2.0755114555358887s, infer: 0.06236004829406738s
# ALSA lib pcm.c:8675:(snd_pcm_recover) underrun occurred
# ALSA lib pcm.c:8675:(snd_pcm_recover) underrun occurred
# ALSA lib pcm.c:8675:(snd_pcm_recover) underrun occurred
# ALSA lib pcm.c:8675:(snd_pcm_recover) underrun occurred
# ALSA lib pcm.c:8675:(snd_pcm_recover) underrun occurred
# ffmpeg version n6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 13.1.1 (GCC) 20230429
#   configuration: --prefix=/usr --disable-debug --disable-static --disable-stripping --enable-amf --enable-avisynth --enable-cuda-llvm --enable-lto --enable-fontconfig --enable-gmp --enable-gnutls --enable-gpl --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libdav1d --enable-libdrm --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libiec61883 --enable-libjack --enable-libjxl --enable-libmfx --enable-libmodplug --enable-libmp3lame --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librav1e --enable-librsvg --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtheora --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxcb --enable-libxml2 --enable-libxvid --enable-libzimg --enable-nvdec --enable-nvenc --enable-opencl --enable-opengl --enable-shared --enable-version3 --enable-vulkan
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mp3, from 'fd:':
#   Duration: N/A, start: 0.000000, bitrate: 48 kb/s
#   Stream #0:0: Audio: mp3, 24000 Hz, mono, fltp, 48 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Output #0, wav, to 'pipe:':
#   Metadata:
#     ISFT            : Lavf60.3.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 24000 Hz, mono, s16, 384 kb/s
#     Metadata:
#       encoder         : Lavc60.3.100 pcm_s16le
# size=     152kB time=00:00:03.21 bitrate= 387.1kbits/s speed=1.1e+03x
# video:0kB audio:152kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.050154%
# Traceback (most recent call last):
#   File "/media/gpt4-pdf-chatbot-langchain/RVC-Speakers/vc_infer_pipeline.py", line 229, in pipeline
#     index = faiss.read_index(file_index)
#   File "/media/gpt4-pdf-chatbot-langchain/pyenv-test-1/lib/python3.10/site-packages/faiss/swigfaiss_avx2.py", line 9783, in read_index
#     return _swigfaiss_avx2.read_index(*args)
# RuntimeError: Error in faiss::InvertedLists* faiss::read_InvertedLists(faiss::IOReader*, int) at /project/faiss/faiss/impl/index_read.cpp:211: Error: 'ret == (n * ails->code_size)' failed: read error in model/lulu/added_IVF256_Flat_nprobe_1_lulu-epoch_v2.index: 3613 != 113664 (Success)
# npy: 0.026470661163330078s, f0: 2.268641948699951s, infer: 0.13264250755310059s
# ffmpeg version n6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 13.1.1 (GCC) 20230429
#   configuration: --prefix=/usr --disable-debug --disable-static --disable-stripping --enable-amf --enable-avisynth --enable-cuda-llvm --enable-lto --enable-fontconfig --enable-gmp --enable-gnutls --enable-gpl --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libdav1d --enable-libdrm --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libiec61883 --enable-libjack --enable-libjxl --enable-libmfx --enable-libmodplug --enable-libmp3lame --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librav1e --enable-librsvg --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtheora --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxcb --enable-libxml2 --enable-libxvid --enable-libzimg --enable-nvdec --enable-nvenc --enable-opencl --enable-opengl --enable-shared --enable-version3 --enable-vulkan
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mp3, from 'fd:':
#   Duration: N/A, start: 0.000000, bitrate: 48 kb/s
#   Stream #0:0: Audio: mp3, 24000 Hz, mono, fltp, 48 kb/s
# Stream mapping:
# ...
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mp3, from 'fd:':
#   Duration: N/A, start: 0.000000, bitrate: 48 kb/s
#   Stream #0:0: Audio: mp3, 24000 Hz, mono, fltp, 48 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Output #0, wav, to 'pipe:':
#   Metadata:
#     ISFT            : Lavf60.3.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 24000 Hz, mono, s16, 384 kb/s
#     Metadata:
#       encoder         : Lavc60.3.100 pcm_s16le
# size=     178kB time=00:00:03.76 bitrate= 386.6kbits/s speed=1.21e+03x
# video:0kB audio:178kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.042853%
# Traceback (most recent call last):
#   File "/media/gpt4-pdf-chatbot-langchain/RVC-Speakers/vc_infer_pipeline.py", line 229, in pipeline
#     index = faiss.read_index(file_index)
#   File "/media/gpt4-pdf-chatbot-langchain/pyenv-test-1/lib/python3.10/site-packages/faiss/swigfaiss_avx2.py", line 9783, in read_index
#     return _swigfaiss_avx2.read_index(*args)
# RuntimeError: Error in faiss::InvertedLists* faiss::read_InvertedLists(faiss::IOReader*, int) at /project/faiss/faiss/impl/index_read.cpp:211: Error: 'ret == (n * ails->code_size)' failed: read error in model/lulu/added_IVF256_Flat_nprobe_1_lulu-epoch_v2.index: 3613 != 113664 (Cannot allocate memory)
# npy: 0.011177301406860352s, f0: 2.467359781265259s, infer: 0.061985015869140625s
# ffmpeg version n6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 13.1.1 (GCC) 20230429
#   configuration: --prefix=/usr --disable-debug --disable-static --disable-stripping --enable-amf --enable-avisynth --enable-cuda-llvm --enable-lto --enable-fontconfig --enable-gmp --enable-gnutls --enable-gpl --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libdav1d --enable-libdrm --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libiec61883 --enable-libjack --enable-libjxl --enable-libmfx --enable-libmodplug --enable-libmp3lame --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librav1e --enable-librsvg --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtheora --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxcb --enable-libxml2 --enable-libxvid --enable-libzimg --enable-nvdec --enable-nvenc --enable-opencl --enable-opengl --enable-shared --enable-version3 --enable-vulkan
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mp3, from 'fd:':
#   Duration: N/A, start: 0.000000, bitrate: 48 kb/s
#   Stream #0:0: Audio: mp3, 24000 Hz, mono, fltp, 48 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Output #0, wav, to 'pipe:':
#   Metadata:
#     ISFT            : Lavf60.3.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 24000 Hz, mono, s16, 384 kb/s
#     Metadata:
#       encoder         : Lavc60.3.100 pcm_s16le
# size=     165kB time=00:00:03.50 bitrate= 386.8kbits/s speed=1.25e+03x
# video:0kB audio:165kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.046060%
# Traceback (most recent call last):
#   File "/media/gpt4-pdf-chatbot-langchain/RVC-Speakers/vc_infer_pipeline.py", line 229, in pipeline
#     index = faiss.read_index(file_index)
#   File "/media/gpt4-pdf-chatbot-langchain/pyenv-test-1/lib/python3.10/site-packages/faiss/swigfaiss_avx2.py", line 9783, in read_index
#     return _swigfaiss_avx2.read_index(*args)
# RuntimeError: Error in faiss::InvertedLists* faiss::read_InvertedLists(faiss::IOReader*, int) at /project/faiss/faiss/impl/index_read.cpp:211: Error: 'ret == (n * ails->code_size)' failed: read error in model/lulu/added_IVF256_Flat_nprobe_1_lulu-epoch_v2.index: 3613 != 113664 (Cannot allocate memory)
# npy: 0.009416580200195312s, f0: 2.4227991104125977s, infer: 0.06105470657348633s
# ffmpeg version n6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 13.1.1 (GCC) 20230429
#   configuration: --prefix=/usr --disable-debug --disable-static --disable-stripping --enable-amf --enable-avisynth --enable-cuda-llvm --enable-lto --enable-fontconfig --enable-gmp --enable-gnutls --enable-gpl --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libdav1d --enable-libdrm --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libiec61883 --enable-libjack --enable-libjxl --enable-libmfx --enable-libmodplug --enable-libmp3lame --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librav1e --enable-librsvg --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtheora --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxcb --enable-libxml2 --enable-libxvid --enable-libzimg --enable-nvdec --enable-nvenc --enable-opencl --enable-opengl --enable-shared --enable-version3 --enable-vulkan
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mp3, from 'fd:':
#   Duration: N/A, start: 0.000000, bitrate: 48 kb/s
#   Stream #0:0: Audio: mp3, 24000 Hz, mono, fltp, 48 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Output #0, wav, to 'pipe:':
#   Metadata:
#     ISFT            : Lavf60.3.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 24000 Hz, mono, s16, 384 kb/s
#     Metadata:
#       encoder         : Lavc60.3.100 pcm_s16le
# size=      99kB time=00:00:02.08 bitrate= 388.7kbits/s speed=1e+03x
# video:0kB audio:99kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.076941%
# Traceback (most recent call last):
#   File "/media/gpt4-pdf-chatbot-langchain/RVC-Speakers/vc_infer_pipeline.py", line 229, in pipeline
#     index = faiss.read_index(file_index)
#   File "/media/gpt4-pdf-chatbot-langchain/pyenv-test-1/lib/python3.10/site-packages/faiss/swigfaiss_avx2.py", line 9783, in read_index
#     return _swigfaiss_avx2.read_index(*args)
# RuntimeError: Error in faiss::InvertedLists* faiss::read_InvertedLists(faiss::IOReader*, int) at /project/faiss/faiss/impl/index_read.cpp:211: Error: 'ret == (n * ails->code_size)' failed: read error in model/lulu/added_IVF256_Flat_nprobe_1_lulu-epoch_v2.index: 3613 != 113664 (Success)
# npy: 0.009403228759765625s, f0: 1.6706428527832031s, infer: 0.05498504638671875s
# ffmpeg version n6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 13.1.1 (GCC) 20230429
#   configuration: --prefix=/usr --disable-debug --disable-static --disable-stripping --enable-amf --enable-avisynth --enable-cuda-llvm --enable-lto --enable-fontconfig --enable-gmp --enable-gnutls --enable-gpl --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libdav1d --enable-libdrm --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libiec61883 --enable-libjack --enable-libjxl --enable-libmfx --enable-libmodplug --enable-libmp3lame --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librav1e --enable-librsvg --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtheora --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxcb --enable-libxml2 --enable-libxvid --enable-libzimg --enable-nvdec --enable-nvenc --enable-opencl --enable-opengl --enable-shared --enable-version3 --enable-vulkan
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mp3, from 'fd:':
#   Duration: N/A, start: 0.000000, bitrate: 48 kb/s
#   Stream #0:0: Audio: mp3, 24000 Hz, mono, fltp, 48 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Output #0, wav, to 'pipe:':
#   Metadata:
#     ISFT            : Lavf60.3.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 24000 Hz, mono, s16, 384 kb/s
#     Metadata:
#       encoder         : Lavc60.3.100 pcm_s16le
# size=     181kB time=00:00:03.84 bitrate= 386.6kbits/s speed=1.33e+03x
# video:0kB audio:181kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.042055%
# Traceback (most recent call last):
#   File "/media/gpt4-pdf-chatbot-langchain/RVC-Speakers/vc_infer_pipeline.py", line 229, in pipeline
#     index = faiss.read_index(file_index)
#   File "/media/gpt4-pdf-chatbot-langchain/pyenv-test-1/lib/python3.10/site-packages/faiss/swigfaiss_avx2.py", line 9783, in read_index
#     return _swigfaiss_avx2.read_index(*args)
# RuntimeError: Error in faiss::InvertedLists* faiss::read_InvertedLists(faiss::IOReader*, int) at /project/faiss/faiss/impl/index_read.cpp:211: Error: 'ret == (n * ails->code_size)' failed: read error in model/lulu/added_IVF256_Flat_nprobe_1_lulu-epoch_v2.index: 3613 != 113664 (Cannot allocate memory)
# npy: 0.010014533996582031s, f0: 2.4657938480377197s, infer: 0.07212281227111816s
# ffmpeg version n6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 13.1.1 (GCC) 20230429
#   configuration: --prefix=/usr --disable-debug --disable-static --disable-stripping --enable-amf --enable-avisynth --enable-cuda-llvm --enable-lto --enable-fontconfig --enable-gmp --enable-gnutls --enable-gpl --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libdav1d --enable-libdrm --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libiec61883 --enable-libjack --enable-libjxl --enable-libmfx --enable-libmodplug --enable-libmp3lame --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librav1e --enable-librsvg --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtheora --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxcb --enable-libxml2 --enable-libxvid --enable-libzimg --enable-nvdec --enable-nvenc --enable-opencl --enable-opengl --enable-shared --enable-version3 --enable-vulkan
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mp3, from 'fd:':
#   Duration: N/A, start: 0.000000, bitrate: 48 kb/s
#   Stream #0:0: Audio: mp3, 24000 Hz, mono, fltp, 48 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Output #0, wav, to 'pipe:':
#   Metadata:
#     ISFT            : Lavf60.3.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 24000 Hz, mono, s16, 384 kb/s
#     Metadata:
#       encoder         : Lavc60.3.100 pcm_s16le
# size=     178kB time=00:00:03.76 bitrate= 386.6kbits/s speed=1.4e+03x
# video:0kB audio:178kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.042853%
# Traceback (most recent call last):
#   File "/media/gpt4-pdf-chatbot-langchain/RVC-Speakers/vc_infer_pipeline.py", line 229, in pipeline
#     index = faiss.read_index(file_index)
#   File "/media/gpt4-pdf-chatbot-langchain/pyenv-test-1/lib/python3.10/site-packages/faiss/swigfaiss_avx2.py", line 9783, in read_index
#     return _swigfaiss_avx2.read_index(*args)
# RuntimeError: Error in faiss::InvertedLists* faiss::read_InvertedLists(faiss::IOReader*, int) at /project/faiss/faiss/impl/index_read.cpp:211: Error: 'ret == (n * ails->code_size)' failed: read error in model/lulu/added_IVF256_Flat_nprobe_1_lulu-epoch_v2.index: 3613 != 113664 (Cannot allocate memory)
# npy: 0.010982275009155273s, f0: 2.2076070308685303s, infer: 0.06216740608215332s
# ffmpeg version n6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 13.1.1 (GCC) 20230429
#   configuration: --prefix=/usr --disable-debug --disable-static --disable-stripping --enable-amf --enable-avisynth --enable-cuda-llvm --enable-lto --enable-fontconfig --enable-gmp --enable-gnutls --enable-gpl --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libdav1d --enable-libdrm --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libiec61883 --enable-libjack --enable-libjxl --enable-libmfx --enable-libmodplug --enable-libmp3lame --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librav1e --enable-librsvg --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtheora --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxcb --enable-libxml2 --enable-libxvid --enable-libzimg --enable-nvdec --enable-nvenc --enable-opencl --enable-opengl --enable-shared --enable-version3 --enable-vulkan
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mp3, from 'fd:':
#   Duration: N/A, start: 0.000000, bitrate: 48 kb/s
#   Stream #0:0: Audio: mp3, 24000 Hz, mono, fltp, 48 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Output #0, wav, to 'pipe:':
#   Metadata:
#     ISFT            : Lavf60.3.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 24000 Hz, mono, s16, 384 kb/s
#     Metadata:
#       encoder         : Lavc60.3.100 pcm_s16le
# size=     140kB time=00:00:02.95 bitrate= 387.3kbits/s speed=1.18e+03x
# video:0kB audio:140kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.054603%
# Traceback (most recent call last):
#   File "/media/gpt4-pdf-chatbot-langchain/RVC-Speakers/vc_infer_pipeline.py", line 229, in pipeline
#     index = faiss.read_index(file_index)
#   File "/media/gpt4-pdf-chatbot-langchain/pyenv-test-1/lib/python3.10/site-packages/faiss/swigfaiss_avx2.py", line 9783, in read_index
#     return _swigfaiss_avx2.read_index(*args)
# RuntimeError: Error in faiss::InvertedLists* faiss::read_InvertedLists(faiss::IOReader*, int) at /project/faiss/faiss/impl/index_read.cpp:211: Error: 'ret == (n * ails->code_size)' failed: read error in model/lulu/added_IVF256_Flat_nprobe_1_lulu-epoch_v2.index: 3613 != 113664 (Success)
# npy: 0.026071548461914062s, f0: 1.9284298419952393s, infer: 0.1286485195159912s
